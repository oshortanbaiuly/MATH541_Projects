# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# %%
data = pd.read_csv('data5.txt', sep = ' ', header = None)
data.columns = ['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10', 'X11', 'X12', 'X13', 'Y']
data
# Out:
#         X1     X2     X3      X4     X5     X6     X7     X8     X9    X10  \
# 0     4.14  -3.44   7.51  11.200  -5.00  -4.36  -7.23  -8.50  10.80  -1.98
# 1    -7.42 -10.30  -4.21  14.800   7.10 -18.40   5.90  11.90  20.50   3.14
# 2   -24.00  12.30 -19.20   4.670  18.70   0.54  14.60   3.14   2.71  13.80
# 3    -9.26   2.02  -9.33   0.826  11.50  -6.96 -11.20 -22.40  -6.45  13.80
# 4   -12.10  -2.05 -15.80  17.900   6.54  10.50   3.60  -7.28  13.00   1.29
# ..     ...    ...    ...     ...    ...    ...    ...    ...    ...    ...
# 295 -11.70   7.57 -11.60  23.500  -1.79  -3.84  -1.52  -7.73  21.40   9.66
# 296  17.30 -19.40  18.90   7.650  -5.89 -11.00  -5.96   5.07   5.06 -16.50
# 297   7.36 -12.10  10.00  -4.960   8.27  -9.52  16.80  20.90 -13.50   2.35
# 298  -3.47  -3.69   3.18  -3.880 -13.10 -13.70 -14.10  -1.40  -2.57  -6.99
# 299  16.50   7.96  10.60  -4.240  27.60 -18.60 -14.10   2.42  -8.66  18.60
#
#         X11     X12    X13       Y
# ...

# %%
X = data.iloc[:, 0:13]
Y = data.iloc[:, 13]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, random_state = 42, shuffle=True)

# %%
data_train = X_train
data_train['Y'] = Y_train
X_train = data_train.iloc[:, 0:13]
data_train
# Out:
#          X1      X2      X3      X4      X5      X6      X7     X8     X9  \
# 194  -2.970  13.100   3.950   1.360  -1.590  29.800  23.400  -2.74   4.15
# 101  -5.740  -2.120   3.300   7.040  -5.220  -6.400  12.900  15.60  12.90
# 68   -5.110   7.890   6.490  -0.983 -11.700  -1.660  16.400  -9.11   4.55
# 224 -17.400  -3.700 -11.900   3.360  -7.250  -0.746  -0.143  -2.23   1.78
# 37   -4.550  -4.990 -11.600   5.170 -14.400  11.300  15.000 -16.20   7.74
# ..      ...     ...     ...     ...     ...     ...     ...    ...    ...
# 188  11.100  12.600   7.490   3.740 -14.600  -0.379  -0.122  20.80   5.22
# 71   -2.730  -1.710  -5.000 -10.200 -13.400  -9.420   5.560 -17.40  -4.59
# 106   2.350  13.500   1.380  -4.450  -0.998  11.500   3.420   5.97 -10.80
# 270   8.010   0.903   9.520  -3.400 -16.300  -4.750 -10.600  12.10  -6.46
# 102  -0.198   4.980  -0.473 -14.300  21.500  19.200   2.850 -20.00 -17.50
#
#         X10    X11    X12     X13       Y
# ...

# %%
X_train
# Out:
#          X1      X2      X3      X4      X5      X6      X7     X8     X9  \
# 194  -2.970  13.100   3.950   1.360  -1.590  29.800  23.400  -2.74   4.15
# 101  -5.740  -2.120   3.300   7.040  -5.220  -6.400  12.900  15.60  12.90
# 68   -5.110   7.890   6.490  -0.983 -11.700  -1.660  16.400  -9.11   4.55
# 224 -17.400  -3.700 -11.900   3.360  -7.250  -0.746  -0.143  -2.23   1.78
# 37   -4.550  -4.990 -11.600   5.170 -14.400  11.300  15.000 -16.20   7.74
# ..      ...     ...     ...     ...     ...     ...     ...    ...    ...
# 188  11.100  12.600   7.490   3.740 -14.600  -0.379  -0.122  20.80   5.22
# 71   -2.730  -1.710  -5.000 -10.200 -13.400  -9.420   5.560 -17.40  -4.59
# 106   2.350  13.500   1.380  -4.450  -0.998  11.500   3.420   5.97 -10.80
# 270   8.010   0.903   9.520  -3.400 -16.300  -4.750 -10.600  12.10  -6.46
# 102  -0.198   4.980  -0.473 -14.300  21.500  19.200   2.850 -20.00 -17.50
#
#         X10    X11    X12     X13
# 194   1.330   7.26 -13.20  15.600
# ...

# %%
Y_train
# Out:
# 194     13.50
# 101    -87.20
# 68      15.50
# 224    -20.30
# 37       5.72
#         ...
# 188   -109.00
# 71      49.50
# 106     -8.91
# 270    -67.50
# 102    179.00
# Name: Y, Length: 210, dtype: float64

# %%
data_test = X_test
data_test['Y'] = Y_test
X_test = data_test.iloc[:, 0:13]
data_test
# Out:
#         X1     X2     X3      X4      X5     X6     X7     X8     X9     X10  \
# 203  11.20 -15.80  14.40 -12.800   1.710  -6.62   3.59 -9.210 -16.30   3.550
# 266  -2.10  -3.18  -4.28   4.390  11.300  -4.93  19.80 -8.260   2.22  10.900
# 152   3.01  -1.11  -4.48   4.880  -0.804   5.97 -22.10  0.444  -4.58  -6.630
# 9    21.60 -10.70  23.00  -6.090  14.600   5.53 -19.10 -4.970  -8.72  10.500
# 233  19.90  15.10  23.80   0.208   3.070 -10.40 -13.70  2.720   5.32  -1.710
# ..     ...    ...    ...     ...     ...    ...    ...    ...    ...     ...
# 114   7.26   2.58   3.39  -1.470  -0.268 -13.30 -13.20  8.320   2.57  -1.960
# 118  -6.17  -4.44  -4.59  19.300 -12.600  15.80  -3.24 -5.260  17.00 -15.600
# 72    4.37   3.89   7.03   9.540   5.220  -2.74  11.80  4.320   9.02  -0.952
# 15    1.80  -1.18  -3.62   5.250  -3.340 -18.40 -12.90  0.661  13.50   0.108
# 10   28.50  13.40  20.00   1.370   0.156   8.89 -14.60 -4.410  -1.81  -2.020
#
#         X11     X12     X13       Y
# ...

# %%
data_train.shape
# Out:
# (210, 14)

# %%
#def covariance(x,y):
#    sum = 0
#    for i in range(len(x)-1):
#        sum += (x[i] - np.mean(x))*(y[i] - np.mean(y))
#        print(sum)
#    return sum / (len(x) - 1)

#covariances = np.zeros(13)

#for i in range(13):
#    covariances[i] = covariance(data_train.iloc[:, i], data_train.iloc[:, -1])

#covariances

# %%
plt.figure(figsize=(15, 15))
correlation_matrix = data_train.corr()
sns.heatmap(correlation_matrix, annot = True, cmap = 'coolwarm')
plt.show()

# %%
print(correlation_matrix)
# Out:
#            X1        X2        X3        X4        X5        X6        X7  \
# X1   1.000000 -0.126214  0.895314 -0.011600 -0.094530 -0.037804 -0.140954
# X2  -0.126214  1.000000 -0.136522 -0.143213  0.115770 -0.115540  0.094172
# X3   0.895314 -0.136522  1.000000 -0.006078 -0.135922 -0.026325 -0.133774
# X4  -0.011600 -0.143213 -0.006078  1.000000  0.088465  0.130147 -0.024134
# X5  -0.094530  0.115770 -0.135922  0.088465  1.000000  0.022658 -0.096994
# X6  -0.037804 -0.115540 -0.026325  0.130147  0.022658  1.000000 -0.012402
# X7  -0.140954  0.094172 -0.133774 -0.024134 -0.096994 -0.012402  1.000000
# X8   0.114312 -0.023571  0.119132  0.052491 -0.010652 -0.085202 -0.007859
# X9   0.019232 -0.156356  0.049778  0.887312  0.037033  0.114448  0.002428
# X10 -0.107263  0.094479 -0.141082  0.060582  0.904310  0.025233 -0.112295
# X11 -0.067862  0.897628 -0.070532 -0.151375  0.078530 -0.123994  0.060963
# X12  0.114528 -0.011275  0.108259  0.032886  0.022285 -0.080808 -0.056745
# ...

# %%
correlation = correlation_matrix.iloc[:,-1]
correlation
# Out:
# X1     0.017686
# X2     0.169065
# X3     0.006639
# X4    -0.334646
# X5     0.475479
# X6     0.024879
# X7    -0.134272
# X8    -0.791981
# X9    -0.301703
# X10    0.423752
# X11    0.130866
# X12   -0.700715
# X13   -0.140852
# Y      1.000000
# Name: Y, dtype: float64

# %%
plt.figure(figsize=(15, 15))
covariance_matrix = data_train.cov()
sns.heatmap(covariance_matrix, annot = True, cmap = 'coolwarm')
plt.show()

# %%
covariance = covariance_matrix.iloc[:,-1]
covariance
# Out:
# X1       11.648579
# X2      113.686372
# X3        3.872471
# X4     -194.082744
# X5      280.593934
# X6       14.507238
# X7      -95.825753
# X8     -553.472653
# X9     -193.956879
# X10     285.889569
# X11      77.566158
# X12    -521.112217
# X13     -89.453521
# Y      3531.000662
# Name: Y, dtype: float64

# %%
covar_corr = np.zeros((14,3))
covar_corr[:,0] = covariance
covar_corr[:,1] = correlation
covar_corr[:,2] = abs(correlation)
covar_corr_vals = pd.DataFrame(covar_corr)
covar_corr_vals.index = ['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10', 'X11', 'X12', 'X13', 'Y']
covar_corr_vals.columns = ['covariance', 'correlation', '|correlation|']
covar_corr_vals
# Out:
#       covariance  correlation  |correlation|
# X1     11.648579     0.017686       0.017686
# X2    113.686372     0.169065       0.169065
# X3      3.872471     0.006639       0.006639
# X4   -194.082744    -0.334646       0.334646
# X5    280.593934     0.475479       0.475479
# X6     14.507238     0.024879       0.024879
# X7    -95.825753    -0.134272       0.134272
# X8   -553.472653    -0.791981       0.791981
# X9   -193.956879    -0.301703       0.301703
# X10   285.889569     0.423752       0.423752
# X11    77.566158     0.130866       0.130866
# X12  -521.112217    -0.700715       0.700715
# X13   -89.453521    -0.140852       0.140852
# Y    3531.000662     1.000000       1.000000

# %%
corr_matrix = pd.DataFrame(correlation_matrix)
corr_matrix
# Out:
#            X1        X2        X3        X4        X5        X6        X7  \
# X1   1.000000 -0.126214  0.895314 -0.011600 -0.094530 -0.037804 -0.140954
# X2  -0.126214  1.000000 -0.136522 -0.143213  0.115770 -0.115540  0.094172
# X3   0.895314 -0.136522  1.000000 -0.006078 -0.135922 -0.026325 -0.133774
# X4  -0.011600 -0.143213 -0.006078  1.000000  0.088465  0.130147 -0.024134
# X5  -0.094530  0.115770 -0.135922  0.088465  1.000000  0.022658 -0.096994
# X6  -0.037804 -0.115540 -0.026325  0.130147  0.022658  1.000000 -0.012402
# X7  -0.140954  0.094172 -0.133774 -0.024134 -0.096994 -0.012402  1.000000
# X8   0.114312 -0.023571  0.119132  0.052491 -0.010652 -0.085202 -0.007859
# X9   0.019232 -0.156356  0.049778  0.887312  0.037033  0.114448  0.002428
# X10 -0.107263  0.094479 -0.141082  0.060582  0.904310  0.025233 -0.112295
# X11 -0.067862  0.897628 -0.070532 -0.151375  0.078530 -0.123994  0.060963
# X12  0.114528 -0.011275  0.108259  0.032886  0.022285 -0.080808 -0.056745
# ...

# %%
linreg = LinearRegression().fit(X_train, list(Y_train))
linreg.coef_
# Out:
# array([ 3.98329913e-03,  4.56300321e-03,  9.97178214e-01, -1.99695855e+00,
#         2.99724507e+00, -1.61843712e-03,  7.63246123e-05, -3.99864305e+00,
#        -9.55522292e-04,  1.86009997e-03,  4.96900126e-01, -1.75246022e-03,
#        -4.99506191e-01])

# %%
linreg.intercept_
# Out:
# 9.994665255521712

# %%
data_train.iloc[2,:]
# Out:
# X1     -5.110
# X2      7.890
# X3      6.490
# X4     -0.983
# X5    -11.700
# X6     -1.660
# X7     16.400
# X8     -9.110
# X9      4.550
# X10   -10.600
# X11     6.640
# X12   -10.700
# X13    15.300
# Y      15.500
# Name: 68, dtype: float64

# %%
res = 0
for i in range(13):
    res = res + data_train.iloc[2,i] * linreg.coef_[i]

res + linreg.intercept_
# Out:
# 15.46047747432427

# %%
data_train.head()
# Out:
#         X1     X2     X3     X4     X5      X6      X7     X8     X9    X10  \
# 194  -2.97  13.10   3.95  1.360  -1.59  29.800  23.400  -2.74   4.15   1.33
# 101  -5.74  -2.12   3.30  7.040  -5.22  -6.400  12.900  15.60  12.90  -3.78
# 68   -5.11   7.89   6.49 -0.983 -11.70  -1.660  16.400  -9.11   4.55 -10.60
# 224 -17.40  -3.70 -11.90  3.360  -7.25  -0.746  -0.143  -2.23   1.78  -8.24
# 37   -4.55  -4.99 -11.60  5.170 -14.40  11.300  15.000 -16.20   7.74 -16.20
#
#       X11   X12    X13      Y
# 194  7.26 -13.2  15.60  13.50
# 101 -5.64  18.0  11.40 -87.20
# 68   6.64 -10.7  15.30  15.50
# 224 -1.33 -10.1  -3.50 -20.30
# 37  -4.14 -12.2   3.46   5.72

# %%
linreg.intercept_
# Out:
# 9.994665255521712

# %%
coefs = [3.98329913e-03,  4.56300321e-03,  9.97178214e-01, -1.99695855e+00,
        2.99724507e+00, -1.61843712e-03,  7.63246123e-05, -3.99864305e+00,
       -9.55522292e-04,  1.86009997e-03,  4.96900126e-01, -1.75246022e-03,
       -4.99506191e-01]

# %%
def check(a,b):
    return a < b

# %%
temp = np.matmul(X_train.transpose(),X_train)
H = np.linalg.inv(temp)
t = np.array([])
for i in range(0,13):
    t = np.append(t, coefs[i]/(err**(1/2)*(H[i,i])**(1/2)))
for i in range(0, len(t)):
    print(i+1, t[i], check(abs(t[i]), 1.968293))
    #if t[i] > 1.968293:
    #    print(f'Х{i} can be discarded with t-value',i, t[i])
# Out:
# 1 1.7107616768690892 True
# 2 1.9410182647099838 True
# 3 374.65442005803413 False
# 4 -773.1826154216291 False
# 5 1104.1878792441519 False
# 6 -1.3861490386558766 True
# 7 0.03070556497443019 True
# 8 -1615.2234617483145 False
# 9 -0.40976863071719244 True
# 10 0.7807950932806896 True
# 11 188.13530477650613 False
# 12 -0.7540503568142192 True
# 13 -179.13095637534977 False
# C:\Users\olzhas.shortanbaiuly\AppData\Local\Temp\ipykernel_19772\1052442249.py:1: FutureWarning: Calling a ufunc on non-aligned DataFrames (or DataFrame/Series combination). Currently, the indices are ignored and the result takes the index/columns of the first DataFrame. In the future , the DataFrames/Series will be aligned before applying the ufunc.
# Convert one of the arguments to a NumPy array (eg 'ufunc(df1, np.asarray(df2)') to keep the current behaviour, or align manually (eg 'df1, df2 = df1.align(df2)') before passing to the ufunc to obtain the future behaviour and silence this warning.
# ...

# %%
t_vals = pd.DataFrame(t)
t_vals.index = ['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10', 'X11', 'X12', 'X13']
t_vals.columns = ['t-value']
t_vals
# Out:
#          t-value
# X1      1.710762
# X2      1.941018
# X3    374.654420
# X4   -773.182615
# X5   1104.187879
# X6     -1.386149
# X7      0.030706
# X8  -1615.223462
# X9     -0.409769
# X10     0.780795
# X11   188.135305
# X12    -0.754050
# X13  -179.130956

# %%
df_t = pd.DataFrame(t)
df_t
# Out:
#               0
# 0      1.710762
# 1      1.941018
# 2    374.654420
# 3   -773.182615
# 4   1104.187879
# 5     -1.386149
# 6      0.030706
# 7  -1615.223462
# 8     -0.409769
# 9      0.780795
# 10   188.135305
# 11    -0.754050
# 12  -179.130956

# %%
from sklearn.metrics import mean_squared_error
reg = LinearRegression()
reg_fit = reg.fit(X_train, list(Y_train))
y_pred = reg_fit.predict(X_test)
err = mean_squared_error(list(Y_test),y_pred)
err
# Out:
# 0.027109956382164388

# %%
linreg.score(X_test, Y_test)
# Out:
# 0.9999892057969771

# %%
X_arr = np.array([data_train.X1,
                 data_train.X2,
                 data_train.X3,
                 data_train.X4,
                 data_train.X5,
                 data_train.X6,
                 data_train.X7,
                 data_train.X8,
                 data_train.X9,
                 data_train.X10,
                 data_train.X11,
                 data_train.X12,
                 data_train.X13,])

# %%
coefs = linreg.intercept_
coefs = coefs.append(linreg.coef_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19772\1360249757.py in <module>
#       1 coefs = linreg.intercept_
# ----> 2 coefs = coefs.append(linreg.coef_)
#
# AttributeError: 'numpy.float64' object has no attribute 'append'

# %%
def reg_m(y, x):
    ones = np.ones(len(x[0]))
    XX = sm.add_constant(np.column_stack((x[0], ones)))
    for ele in x[1:]:
        XX = sm.add_constant(np.column_stack((ele, XX)))
    results = sm.OLS(y, XX).fit()
    return results

print(reg_m(list(data_train["Y"]), X_arr).summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.076e+06
# Date:                Sun, 26 Feb 2023   Prob (F-statistic):               0.00
# Time:                        22:26:13   Log-Likelihood:                 87.204
# No. Observations:                 210   AIC:                            -146.4
# Df Residuals:                     196   BIC:                            -99.55
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.4995      0.003   -177.701      0.000      -0.505      -0.494
# ...

# %%
coef = [-0.4995, -0.0018, 0.4969, 0.0019, -0.0010, -3.9986, 7.632e-05, -0.0016, 2.9972, -1.9970, 0.9972, 0.0046, 0.0040, 9.9947]
y_predicted = coefs[0]*data.X1 + + coefs[1]*data.X2+ coefs[2]*data.X3+ coefs[3]*data.X4+ coefs[4]*data.X5+ coefs[5]*data.X6 + coefs[6]*data.X7+ coefs[7]*data.X8+ coefs[8]*data.X9+ coefs[9]*data.X10+ coefs[10]*data.X11+ coefs[11]*data.X12+ coefs[12]*data.X13 + coefs[13]

y_predicted

# %%
res = np.zeros(shape = (len(Y_test)))
Yy = list(Y)
for i in range(len(y_pred)):
    res[i] = Yy[i] - y_pred[i]

sm.qqplot(res)
plt.show()

# %%
sm.qqplot(res,line='q') # 'q' - A line is fit through the quartiles # line = '45'- to draw the 45-degree diagonal line
plt.title("Q-Q plot for residuals")
# Out:
# Text(0.5, 1.0, 'Q-Q plot for residuals')

# %%
plt.scatter(y_pred, res)
plt.axhline(y = 0)
plt.xlabel('predicted y')
plt.ylabel('residuals')
plt.title("Residuals against predicted y")
# Out:
# Text(0.5, 1.0, 'Residuals against predicted y')

# %%
r2_score(Y_test,y_pred)
# Out:
# 0.9999892057969771

# %%
res
# Out:
# array([-0.06068777, -0.12659998, -0.16025236,  0.27583565,  0.25379813,
#        -0.08392112,  0.00633887, -0.19592167,  0.02368215, -0.06278108,
#         0.02154289, -0.06963829,  0.19606629,  0.38616409,  0.06494738,
#        -0.0786506 ,  0.06304691, -0.08503327,  0.01226908, -0.27411263,
#         0.15590011,  0.09789474,  0.00796377,  0.10072868, -0.18532363,
#        -0.04075051, -0.18077133,  0.29695431,  0.16798931,  0.10551664,
#        -0.04570856,  0.16543582, -0.13124834, -0.00624186,  0.16867168,
#         0.04486938,  0.20883748,  0.09341897,  0.09370436, -0.03585579,
#         0.12335936,  0.14812875,  0.06484852, -0.55079771, -0.19911344,
#         0.09005331, -0.05867216, -0.0353744 , -0.36963745,  0.03219555,
#        -0.21191361, -0.34414507, -0.06605732,  0.17733978, -0.38541025,
#        -0.04191892,  0.01090306,  0.27869906,  0.03244014, -0.16347552,
#        -0.18406043,  0.06223634, -0.03033934, -0.03870002, -0.19215777,
# ...

# %%
beta = np.dot((np.dot(np.linalg.inv(np.dot(X_train.T,X_train)),X_train.T)),y_train)
print(beta)

# %%
linreg = LinearRegression().fit(X_train, y_train)
linreg.coef_

# %%
def covariance(x, y):
    mean_x = x.mean()
    mean_y = y.mean()

    sub_x = [i - mean_x for i in x]
    sub_y = [i - mean_y for i in y]

    numerator = sum([sub_x[i]*sub_y[i] for i in range(len(sub_x))])
    denominator = len(x)-1

    return numerator/denominator

covariance(data_train.iloc[:,3], data_train.iloc[:,-1])

# %%
correlation_matrix[[12]]

# %%
sns.set(rc = {'figure.figsize':(16,8)})
sns.heatmap(df.corr(), annot = True, fmt='.2g',cmap= 'coolwarm')

# %%
covariances = np.cov(X, Y)
covariances

# %%
covariances[:, -1]
